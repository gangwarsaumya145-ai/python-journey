# %% [markdown]
# <a href="https://colab.research.google.com/github/gangwarsaumya145-ai/python-journey/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('saumya is future ceo', end = ' ')
print('her brand name is', 'ciya', sep = ' - ')
# Out:
# saumya is future ceo her brand name is - ciya

# %%
value = 4 * 2.5
print(type(value))
# Out:
# <class 'float'>

# %%
a = int(input('enter first number: '))
b = int(input('enter second number: '))
print('sum =', a+b )
print('multiply=', a*b )
# Out:
# enter first number: 456678
# enter second number: 5678
# sum = 462356
# multiply= 2593017684
