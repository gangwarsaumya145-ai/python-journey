# %% [markdown]
# <a href="https://colab.research.google.com/github/gangwarsaumya145-ai/python-journey/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#here are my print statements that print 1-3
print("one")
print('two')
print('three')

#Here's a single line comment

#Here's a
#multi-line comment
#on multiple lines
# Out:
# one
# two
# three

# %%
#this code will:
#prompt for your name
#set the "name" varible
#print a message
name = input("what is your name?") #get user name
print('hello' + ' ' + name) #print a message with the users's name
mood = input('how are you feeling?')
print('you are feeling' + ' ' + mood)
print('nice to meet you' + ' ' + name)
